# %% [markdown]
# ## Black-box Vector Optimization on Fairness
# This notebook contains a vector optimization example on an ML fairness dataset, and compares Naive Elimination and PaVeBa algorithms.

# %%
import warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.INFO)

import vopy.algorithms
from vopy.utils import set_seed
from vopy.order import ConeTheta2DOrder
from vopy.datasets import get_dataset_instance
from vopy.utils.evaluate import calculate_epsilonF1_score

# %% [markdown]
# Let's first create an `Order` object to define our preference and visualize it's cone. Our preference correspond to allowing a little trade-off between objectives.

# %%
order = ConeTheta2DOrder(cone_degree=100)
fig_cone = order.ordering_cone.plot()

# %% [markdown]
# Now, we will create an instance of ML fairness dataset and visualize its Pareto front w.r.t. the order we created. This dataset contains different (200 candidates) hyperparameter selections of ROAD approach on a neural network architecture. The objectives are negative global unfairness measured by disparate impact measure and accuracy of the model. The $x$-axis corresponds to the negative global unfairness and $y$-axis corresponds to the accuracy of the model.

# %%
dataset_name = "Fairness"
dataset = get_dataset_instance(dataset_name)
fig_pareto = order.plot_pareto_set(dataset.out_data)

# %% [markdown]
# As you can see, there are a lot of hyperparameter combinations that give $0$ unfairness (right end of the plot), but due to our encoded preference, only the one with the highest accuracy is among the Pareto front. There are $3$ candidates that are Pareto.

# %% [markdown]
# #### Algorithms
# We'll now run both algorithms (Naive Elimination and PaVeBa) and print out their results.

# %%
epsilon = 0.01
delta = 0.05
noise_var = epsilon

set_seed(0)

algorithm = vopy.algorithms.PaVeBaGP(
    epsilon=epsilon, delta=delta,
    dataset_name=dataset_name, order=order, noise_var=noise_var,
    type='IH', conf_contraction=64
)

while True:
    is_done = algorithm.run_one_step()

    if is_done:
        break

pred_pareto_indices = sorted(list(algorithm.P))
pareto_indices = order.get_pareto_set(dataset.out_data)

eps_f1 = calculate_epsilonF1_score(
    dataset, order, pareto_indices, pred_pareto_indices, epsilon
)
print(f"PaVeBaGP - epsilon-F1 Score: {eps_f1:.2f}")
print(f"PaVeBaGP - Number of observations: {algorithm.sample_count}")
# Out:
# INFO:root:Training started.
# INFO:root:Training done.
# INFO:root:Round 1:Evaluating
# INFO:root:Round 1:Modeling
# INFO:root:Round 1:Discarding
# INFO:root:Round 1:Pareto update
# INFO:root:Round 1:Useful update
# INFO:root:Round 1:There are 200 designs left in set S and 0 designs in set P.
# INFO:root:Round 1:Sample count 1
# INFO:root:Round 2:Evaluating
# INFO:root:Round 2:Modeling
# INFO:root:Round 2:Discarding
# INFO:root:Round 2:Pareto update
# INFO:root:Round 2:Useful update
# INFO:root:Round 2:There are 199 designs left in set S and 0 designs in set P.
# INFO:root:Round 2:Sample count 2
# INFO:root:Round 3:Evaluating
# INFO:root:Round 3:Modeling
# INFO:root:Round 3:Discarding
# INFO:root:Round 3:Pareto update
# INFO:root:Round 3:Useful update
# INFO:root:Round 3:There are 198 designs left in set S and 0 designs in set P.
# INFO:root:Round 3:Sample count 3
# INFO:root:Round 4:Evaluating
# INFO:root:Round 4:Modeling
# INFO:root:Round 4:Discarding
# INFO:root:Round 4:Pareto update
# INFO:root:Round 4:Useful update
# INFO:root:Round 4:There are 198 designs left in set S and 0 designs in set P.
# INFO:root:Round 4:Sample count 4
# INFO:root:Round 5:Evaluating
# INFO:root:Round 5:Modeling
# INFO:root:Round 5:Discarding
# INFO:root:Round 5:Pareto update
# INFO:root:Round 5:Useful update
# INFO:root:Round 5:There are 197 designs left in set S and 0 designs in set P.
# INFO:root:Round 5:Sample count 5
# INFO:root:Round 6:Evaluating
# INFO:root:Round 6:Modeling
# INFO:root:Round 6:Discarding
# INFO:root:Round 6:Pareto update
# INFO:root:Round 6:Useful update
# INFO:root:Round 6:There are 196 designs left in set S and 0 designs in set P.
# INFO:root:Round 6:Sample count 6
# INFO:root:Round 7:Evaluating
# INFO:root:Round 7:Modeling
# INFO:root:Round 7:Discarding
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#       7 algorithm = vopy.algorithms.PaVeBaGP(
#       8     epsilon=epsilon, delta=delta,
#       9     dataset_name=dataset_name, order=order, noise_var=noise_var,
#      10     type='DE', conf_contraction=64
#      11 )
#      13 while True:
# ---> 14     is_done = algorithm.run_one_step()
#      16     if is_done:
#      17         break
#
# File ~/Work/VOPy/vopy/algorithms/paveba_gp.py:237, in PaVeBaGP.run_one_step(self)
#     234 self.modeling()
#     236 logging.info(f"{round_str}:Discarding")
# --> 237 self.discarding()
#     239 logging.info(f"{round_str}:Pareto update")
#     240 self.pareto_updating()
#
# File ~/Work/VOPy/vopy/algorithms/paveba_gp.py:147, in PaVeBaGP.discarding(self)
#     143     continue
#     145 pt_p_conf = self.design_space.confidence_regions[pt_prime]
# --> 147 if confidence_region_is_dominated(self.order, pt_conf, pt_p_conf, 0):
#     148     to_be_discarded.append(pt)
#     149     break
#
# File ~/Work/VOPy/vopy/confidence_region.py:489, in confidence_region_is_dominated(order, region1, region2, slackness)
#     487     return RectangularConfidenceRegion.is_dominated(order, region1, region2, slackness)
#     488 elif isinstance(region1, EllipsoidalConfidenceRegion):
# --> 489     return EllipsoidalConfidenceRegion.is_dominated(order, region1, region2, slackness)
#     490 else:
#     491     raise NotImplementedError
#
# File ~/Work/VOPy/vopy/confidence_region.py:369, in EllipsoidalConfidenceRegion.is_dominated(cls, order, obj1, obj2, slackness)
#     367 prob = cp.Problem(objective, constraints)
#     368 try:
# --> 369     prob.solve()
#     370 except cp.error.SolverError:
#     371     prob.solve(solver=cp.SCS)
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/problems/problem.py:503, in Problem.solve(self, *args, **kwargs)
#     501 else:
#     502     solve_func = Problem._solve
# --> 503 return solve_func(self, *args, **kwargs)
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/problems/problem.py:1073, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1070         self.unpack(chain.retrieve(soln))
#    1071         return self.value
# -> 1073 data, solving_chain, inverse_data = self.get_problem_data(
#    1074     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1075 )
#    1077 if verbose:
#    1078     print(_NUM_SOLVER_STR)
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/problems/problem.py:696, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     693     s.LOGGER.info(
#     694              'Compiling problem (target solver=%s).', solver_name)
#     695     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 696 data, inverse_data = solving_chain.apply(self, verbose)
#     697 safe_to_cache = (
#     698     isinstance(data, dict)
#     699     and s.PARAM_PROB in data
#     700     and not any(isinstance(reduction, EvalParams)
#     701                 for reduction in solving_chain.reductions)
#     702 )
#     703 self._compilation_time = time.time() - start
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/reductions/chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/reductions/dcp2cone/dcp2cone.py:55, in Dcp2Cone.apply(self, problem)
#      51     raise ValueError("Cannot reduce problem to cone program")
#      53 inverse_data = InverseData(problem)
# ---> 55 canon_objective, canon_constraints = self.canonicalize_tree(
#      56     problem.objective, True)
#      58 for constraint in problem.constraints:
#      59     # canon_constr is the constraint rexpressed in terms of
#      60     # its canonicalized arguments, and aux_constr are the constraints
#      61     # generated while canonicalizing the arguments of the original
#      62     # constraint
#      63     canon_constr, aux_constr = self.canonicalize_tree(
#      64         constraint, False)
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/reductions/dcp2cone/dcp2cone.py:99, in Dcp2Cone.canonicalize_tree(self, expr, affine_above)
#      97         canon_args += [canon_arg]
#      98         constrs += c
# ---> 99     canon_expr, c = self.canonicalize_expr(expr, canon_args, affine_above)
#     100     constrs += c
#     101 return canon_expr, constrs
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/reductions/dcp2cone/dcp2cone.py:131, in Dcp2Cone.canonicalize_expr(self, expr, args, affine_above)
#     128 if type(expr) in self.cone_canon_methods:
#     129     return self.cone_canon_methods[type(expr)](expr, args)
# --> 131 return expr.copy(args), []
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/utilities/canonical.py:103, in Canonical.copy(self, args, id_objects)
#     101     return type(self)(*(args + data))
#     102 else:
# --> 103     return type(self)(*args)
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/problems/objective.py:44, in Objective.__init__(self, expr)
#      42 self.args = [Expression.cast_to_const(expr)]
#      43 # Validate that the objective resolves to a scalar.
# ---> 44 if not self.args[0].is_scalar():
#      45     raise ValueError("The '%s' objective must resolve to a scalar."
#      46                      % self.NAME)
#      47 if not self.args[0].is_real():
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/expressions/expression.py:488, in Expression.is_scalar(self)
#     485 def is_scalar(self) -> bool:
#     486     """Is the expression a scalar?
#     487     """
# --> 488     return all(d == 1 for d in self.shape)
#
# File ~/mamba/envs/vopy/lib/python3.12/site-packages/cvxpy/atoms/atom.py:79, in Atom.shape(self)
#      75     """Returns the shape of the expression.
#      76     """
#      77     raise NotImplementedError()
# ---> 79 @property
#      80 def shape(self) -> Tuple[int, ...]:
#      81     return self._shape
#      83 @abc.abstractmethod
#      84 def sign_from_args(self) -> Tuple[bool, bool]:
#
# KeyboardInterrupt:

# %% [markdown]
# The results show both Naive Elimination and PaVeBa achieve perfect results but with different number of samples. This is expected due to the nature of the algorithms. For details of the algorithms, see documentation for [vopy.algorithms](../algorithms.rst).
