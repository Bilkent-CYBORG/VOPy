# %% [markdown]
# ## Black-box Vector Optimization on Fairness
# This notebook contains a vector optimization example on an ML fairness dataset, and compares Naive Elimination and PaVeBa algorithms.

# %%
import warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.INFO)

import vopy.algorithms
from vopy.utils import set_seed
from vopy.order import ConeTheta2DOrder
from vopy.datasets import get_dataset_instance
from vopy.utils.evaluate import calculate_epsilonF1_score

# %% [markdown]
# Let's first create an `Order` object to define our preference and visualize it's cone. Our preference correspond to allowing a little trade-off between objectives.

# %%
order = ConeTheta2DOrder(cone_degree=100)
fig_cone = order.ordering_cone.plot()

# %% [markdown]
# Now, we will create an instance of ML fairness dataset and visualize its Pareto front w.r.t. the order we created. This dataset contains different (200 candidates) hyperparameter selections of ROAD approach on a neural network architecture. The objectives are negative global unfairness measured by disparate impact measure and accuracy of the model. The $x$-axis corresponds to the negative global unfairness and $y$-axis corresponds to the accuracy of the model.

# %%
dataset_name = "Fairness"
dataset = get_dataset_instance(dataset_name)
fig_pareto = order.plot_pareto_set(dataset.out_data)

# %% [markdown]
# As you can see, there are a lot of hyperparameter combinations that give $0$ unfairness (right end of the plot), but due to our encoded preference, only the one with the highest accuracy is among the Pareto front. There are $3$ candidates that are Pareto.

# %% [markdown]
# #### Algorithms
# We'll now run both algorithms (Naive Elimination and PaVeBa) and print out their results.

# %%
epsilon = 0.01
delta = 0.05
noise_var = epsilon

set_seed(0)

algorithm = vopy.algorithms.PaVeBaGP(
    epsilon=epsilon, delta=delta,
    dataset_name=dataset_name, order=order, noise_var=noise_var,
    type='IH', conf_contraction=128
)

while True:
    is_done = algorithm.run_one_step()

    if is_done:
        break

pred_pareto_indices = sorted(list(algorithm.P))
pareto_indices = order.get_pareto_set(dataset.out_data)

eps_f1 = calculate_epsilonF1_score(
    dataset, order, pareto_indices, pred_pareto_indices, epsilon
)
print(f"PaVeBaGP - epsilon-F1 Score: {eps_f1:.2f}")
print(f"PaVeBaGP - Number of observations: {algorithm.sample_count}")
# Out:
# INFO:root:Training started.
# INFO:root:Training done.
# INFO:root:Round 1:Evaluating
# INFO:root:Round 1:Modeling
# INFO:root:Round 1:Discarding
# INFO:root:Round 1:Pareto update
# INFO:root:Round 1:Useful update
# INFO:root:Round 1:There are 200 designs left in set S and 0 designs in set P.
# INFO:root:Round 1:Sample count 1
# INFO:root:Round 2:Evaluating
# INFO:root:Round 2:Modeling
# INFO:root:Round 2:Discarding
# INFO:root:Round 2:Pareto update
# INFO:root:Round 2:Useful update
# INFO:root:Round 2:There are 200 designs left in set S and 0 designs in set P.
# INFO:root:Round 2:Sample count 2
# INFO:root:Round 3:Evaluating
# INFO:root:Round 3:Modeling
# INFO:root:Round 3:Discarding
# INFO:root:Round 3:Pareto update
# INFO:root:Round 3:Useful update
# INFO:root:Round 3:There are 199 designs left in set S and 0 designs in set P.
# INFO:root:Round 3:Sample count 3
# INFO:root:Round 4:Evaluating
# INFO:root:Round 4:Modeling
# INFO:root:Round 4:Discarding
# INFO:root:Round 4:Pareto update
# INFO:root:Round 4:Useful update
# INFO:root:Round 4:There are 199 designs left in set S and 0 designs in set P.
# INFO:root:Round 4:Sample count 4
# INFO:root:Round 5:Evaluating
# INFO:root:Round 5:Modeling
# INFO:root:Round 5:Discarding
# INFO:root:Round 5:Pareto update
# INFO:root:Round 5:Useful update
# INFO:root:Round 5:There are 199 designs left in set S and 0 designs in set P.
# INFO:root:Round 5:Sample count 5
# INFO:root:Round 6:Evaluating
# INFO:root:Round 6:Modeling
# INFO:root:Round 6:Discarding
# INFO:root:Round 6:Pareto update
# INFO:root:Round 6:Useful update
# INFO:root:Round 6:There are 199 designs left in set S and 0 designs in set P.
# INFO:root:Round 6:Sample count 6
# INFO:root:Round 7:Evaluating
# INFO:root:Round 7:Modeling
# INFO:root:Round 7:Discarding
# INFO:root:Round 7:Pareto update
# INFO:root:Round 7:Useful update
# INFO:root:Round 7:There are 198 designs left in set S and 0 designs in set P.
# INFO:root:Round 7:Sample count 7
# INFO:root:Round 8:Evaluating
# INFO:root:Round 8:Modeling
# INFO:root:Round 8:Discarding
# INFO:root:Round 8:Pareto update
# INFO:root:Round 8:Useful update
# INFO:root:Round 8:There are 196 designs left in set S and 0 designs in set P.
# INFO:root:Round 8:Sample count 8
# INFO:root:Round 9:Evaluating
# INFO:root:Round 9:Modeling
# INFO:root:Round 9:Discarding
# INFO:root:Round 9:Pareto update
# INFO:root:Round 9:Useful update
# INFO:root:Round 9:There are 195 designs left in set S and 0 designs in set P.
# INFO:root:Round 9:Sample count 9
# INFO:root:Round 10:Evaluating
# INFO:root:Round 10:Modeling
# INFO:root:Round 10:Discarding
# INFO:root:Round 10:Pareto update
# INFO:root:Round 10:Useful update
# INFO:root:Round 10:There are 195 designs left in set S and 0 designs in set P.
# INFO:root:Round 10:Sample count 10
# INFO:root:Round 11:Evaluating
# INFO:root:Round 11:Modeling
# INFO:root:Round 11:Discarding
# INFO:root:Round 11:Pareto update
# INFO:root:Round 11:Useful update
# INFO:root:Round 11:There are 195 designs left in set S and 0 designs in set P.
# INFO:root:Round 11:Sample count 11
# INFO:root:Round 12:Evaluating
# INFO:root:Round 12:Modeling
# INFO:root:Round 12:Discarding
# INFO:root:Round 12:Pareto update
# INFO:root:Round 12:Useful update
# INFO:root:Round 12:There are 195 designs left in set S and 0 designs in set P.
# INFO:root:Round 12:Sample count 12
# INFO:root:Round 13:Evaluating
# INFO:root:Round 13:Modeling
# INFO:root:Round 13:Discarding
# INFO:root:Round 13:Pareto update
# INFO:root:Round 13:Useful update
# INFO:root:Round 13:There are 194 designs left in set S and 0 designs in set P.
# INFO:root:Round 13:Sample count 13
# INFO:root:Round 14:Evaluating
# INFO:root:Round 14:Modeling
# INFO:root:Round 14:Discarding
# INFO:root:Round 14:Pareto update
# INFO:root:Round 14:Useful update
# INFO:root:Round 14:There are 194 designs left in set S and 0 designs in set P.
# INFO:root:Round 14:Sample count 14
# INFO:root:Round 15:Evaluating
# INFO:root:Round 15:Modeling
# INFO:root:Round 15:Discarding
# INFO:root:Round 15:Pareto update
# INFO:root:Round 15:Useful update
# INFO:root:Round 15:There are 194 designs left in set S and 0 designs in set P.
# INFO:root:Round 15:Sample count 15
# INFO:root:Round 16:Evaluating
# INFO:root:Round 16:Modeling
# INFO:root:Round 16:Discarding
# INFO:root:Round 16:Pareto update
# INFO:root:Round 16:Useful update
# INFO:root:Round 16:There are 193 designs left in set S and 0 designs in set P.
# INFO:root:Round 16:Sample count 16
# INFO:root:Round 17:Evaluating
# INFO:root:Round 17:Modeling
# INFO:root:Round 17:Discarding
# INFO:root:Round 17:Pareto update
# INFO:root:Round 17:Useful update
# INFO:root:Round 17:There are 192 designs left in set S and 0 designs in set P.
# INFO:root:Round 17:Sample count 17
# INFO:root:Round 18:Evaluating
# INFO:root:Round 18:Modeling
# INFO:root:Round 18:Discarding
# INFO:root:Round 18:Pareto update
# INFO:root:Round 18:Useful update
# INFO:root:Round 18:There are 191 designs left in set S and 0 designs in set P.
# INFO:root:Round 18:Sample count 18
# INFO:root:Round 19:Evaluating
# INFO:root:Round 19:Modeling
# INFO:root:Round 19:Discarding
# INFO:root:Round 19:Pareto update
# INFO:root:Round 19:Useful update
# INFO:root:Round 19:There are 189 designs left in set S and 0 designs in set P.
# INFO:root:Round 19:Sample count 19
# INFO:root:Round 20:Evaluating
# INFO:root:Round 20:Modeling
# INFO:root:Round 20:Discarding
# INFO:root:Round 20:Pareto update
# INFO:root:Round 20:Useful update
# INFO:root:Round 20:There are 189 designs left in set S and 0 designs in set P.
# INFO:root:Round 20:Sample count 20
# INFO:root:Round 21:Evaluating
# INFO:root:Round 21:Modeling
# INFO:root:Round 21:Discarding
# INFO:root:Round 21:Pareto update
# INFO:root:Round 21:Useful update
# INFO:root:Round 21:There are 189 designs left in set S and 0 designs in set P.
# INFO:root:Round 21:Sample count 21
# INFO:root:Round 22:Evaluating
# INFO:root:Round 22:Modeling
# INFO:root:Round 22:Discarding
# INFO:root:Round 22:Pareto update
# INFO:root:Round 22:Useful update
# INFO:root:Round 22:There are 189 designs left in set S and 0 designs in set P.
# INFO:root:Round 22:Sample count 22
# INFO:root:Round 23:Evaluating
# INFO:root:Round 23:Modeling
# INFO:root:Round 23:Discarding
# INFO:root:Round 23:Pareto update
# INFO:root:Round 23:Useful update
# INFO:root:Round 23:There are 188 designs left in set S and 0 designs in set P.
# INFO:root:Round 23:Sample count 23
# INFO:root:Round 24:Evaluating
# INFO:root:Round 24:Modeling
# INFO:root:Round 24:Discarding
# INFO:root:Round 24:Pareto update
# INFO:root:Round 24:Useful update
# INFO:root:Round 24:There are 187 designs left in set S and 0 designs in set P.
# INFO:root:Round 24:Sample count 24
# INFO:root:Round 25:Evaluating
# INFO:root:Round 25:Modeling
# INFO:root:Round 25:Discarding
# INFO:root:Round 25:Pareto update
# INFO:root:Round 25:Useful update
# INFO:root:Round 25:There are 186 designs left in set S and 0 designs in set P.
# INFO:root:Round 25:Sample count 25
# INFO:root:Round 26:Evaluating
# INFO:root:Round 26:Modeling
# INFO:root:Round 26:Discarding
# INFO:root:Round 26:Pareto update
# INFO:root:Round 26:Useful update
# INFO:root:Round 26:There are 185 designs left in set S and 0 designs in set P.
# INFO:root:Round 26:Sample count 26
# INFO:root:Round 27:Evaluating
# INFO:root:Round 27:Modeling
# INFO:root:Round 27:Discarding
# INFO:root:Round 27:Pareto update
# INFO:root:Round 27:Useful update
# INFO:root:Round 27:There are 185 designs left in set S and 0 designs in set P.
# INFO:root:Round 27:Sample count 27
# INFO:root:Round 28:Evaluating
# INFO:root:Round 28:Modeling
# INFO:root:Round 28:Discarding
# INFO:root:Round 28:Pareto update
# INFO:root:Round 28:Useful update
# INFO:root:Round 28:There are 185 designs left in set S and 0 designs in set P.
# INFO:root:Round 28:Sample count 28
# INFO:root:Round 29:Evaluating
# INFO:root:Round 29:Modeling
# INFO:root:Round 29:Discarding
# INFO:root:Round 29:Pareto update
# INFO:root:Round 29:Useful update
# INFO:root:Round 29:There are 184 designs left in set S and 0 designs in set P.
# INFO:root:Round 29:Sample count 29
# INFO:root:Round 30:Evaluating
# INFO:root:Round 30:Modeling
# INFO:root:Round 30:Discarding
# INFO:root:Round 30:Pareto update
# INFO:root:Round 30:Useful update
# INFO:root:Round 30:There are 183 designs left in set S and 0 designs in set P.
# INFO:root:Round 30:Sample count 30
# INFO:root:Round 31:Evaluating
# INFO:root:Round 31:Modeling
# INFO:root:Round 31:Discarding
# INFO:root:Round 31:Pareto update
# INFO:root:Round 31:Useful update
# INFO:root:Round 31:There are 182 designs left in set S and 0 designs in set P.
# INFO:root:Round 31:Sample count 31
# INFO:root:Round 32:Evaluating
# INFO:root:Round 32:Modeling
# INFO:root:Round 32:Discarding
# INFO:root:Round 32:Pareto update
# INFO:root:Round 32:Useful update
# INFO:root:Round 32:There are 181 designs left in set S and 0 designs in set P.
# INFO:root:Round 32:Sample count 32
# INFO:root:Round 33:Evaluating
# INFO:root:Round 33:Modeling
# INFO:root:Round 33:Discarding
# INFO:root:Round 33:Pareto update
# INFO:root:Round 33:Useful update
# INFO:root:Round 33:There are 180 designs left in set S and 0 designs in set P.
# INFO:root:Round 33:Sample count 33
# INFO:root:Round 34:Evaluating
# INFO:root:Round 34:Modeling
# INFO:root:Round 34:Discarding
# INFO:root:Round 34:Pareto update
# INFO:root:Round 34:Useful update
# INFO:root:Round 34:There are 179 designs left in set S and 0 designs in set P.
# INFO:root:Round 34:Sample count 34
# INFO:root:Round 35:Evaluating
# INFO:root:Round 35:Modeling
# INFO:root:Round 35:Discarding
# INFO:root:Round 35:Pareto update
# INFO:root:Round 35:Useful update
# INFO:root:Round 35:There are 178 designs left in set S and 0 designs in set P.
# INFO:root:Round 35:Sample count 35
# INFO:root:Round 36:Evaluating
# INFO:root:Round 36:Modeling
# INFO:root:Round 36:Discarding
# INFO:root:Round 36:Pareto update
# INFO:root:Round 36:Useful update
# INFO:root:Round 36:There are 177 designs left in set S and 0 designs in set P.
# INFO:root:Round 36:Sample count 36
# INFO:root:Round 37:Evaluating
# INFO:root:Round 37:Modeling
# INFO:root:Round 37:Discarding
# INFO:root:Round 37:Pareto update
# INFO:root:Round 37:Useful update
# INFO:root:Round 37:There are 176 designs left in set S and 0 designs in set P.
# INFO:root:Round 37:Sample count 37
# INFO:root:Round 38:Evaluating
# INFO:root:Round 38:Modeling
# INFO:root:Round 38:Discarding
# INFO:root:Round 38:Pareto update
# INFO:root:Round 38:Useful update
# INFO:root:Round 38:There are 175 designs left in set S and 0 designs in set P.
# INFO:root:Round 38:Sample count 38
# INFO:root:Round 39:Evaluating
# INFO:root:Round 39:Modeling
# INFO:root:Round 39:Discarding
# INFO:root:Round 39:Pareto update
# INFO:root:Round 39:Useful update
# INFO:root:Round 39:There are 174 designs left in set S and 0 designs in set P.
# INFO:root:Round 39:Sample count 39
# INFO:root:Round 40:Evaluating
# INFO:root:Round 40:Modeling
# INFO:root:Round 40:Discarding
# INFO:root:Round 40:Pareto update
# INFO:root:Round 40:Useful update
# INFO:root:Round 40:There are 173 designs left in set S and 0 designs in set P.
# INFO:root:Round 40:Sample count 40
# INFO:root:Round 41:Evaluating
# INFO:root:Round 41:Modeling
# INFO:root:Round 41:Discarding
# INFO:root:Round 41:Pareto update
# INFO:root:Round 41:Useful update
# INFO:root:Round 41:There are 172 designs left in set S and 0 designs in set P.
# INFO:root:Round 41:Sample count 41
# INFO:root:Round 42:Evaluating
# INFO:root:Round 42:Modeling
# INFO:root:Round 42:Discarding
# INFO:root:Round 42:Pareto update
# INFO:root:Round 42:Useful update
# INFO:root:Round 42:There are 171 designs left in set S and 0 designs in set P.
# INFO:root:Round 42:Sample count 42
# INFO:root:Round 43:Evaluating
# INFO:root:Round 43:Modeling
# INFO:root:Round 43:Discarding
# INFO:root:Round 43:Pareto update
# INFO:root:Round 43:Useful update
# INFO:root:Round 43:There are 171 designs left in set S and 0 designs in set P.
# INFO:root:Round 43:Sample count 43
# INFO:root:Round 44:Evaluating
# INFO:root:Round 44:Modeling
# INFO:root:Round 44:Discarding
# INFO:root:Round 44:Pareto update
# INFO:root:Round 44:Useful update
# INFO:root:Round 44:There are 170 designs left in set S and 0 designs in set P.
# INFO:root:Round 44:Sample count 44
# INFO:root:Round 45:Evaluating
# INFO:root:Round 45:Modeling
# INFO:root:Round 45:Discarding
# INFO:root:Round 45:Pareto update
# INFO:root:Round 45:Useful update
# INFO:root:Round 45:There are 170 designs left in set S and 0 designs in set P.
# INFO:root:Round 45:Sample count 45
# INFO:root:Round 46:Evaluating
# INFO:root:Round 46:Modeling
# INFO:root:Round 46:Discarding
# INFO:root:Round 46:Pareto update
# INFO:root:Round 46:Useful update
# INFO:root:Round 46:There are 169 designs left in set S and 0 designs in set P.
# INFO:root:Round 46:Sample count 46
# INFO:root:Round 47:Evaluating
# INFO:root:Round 47:Modeling
# INFO:root:Round 47:Discarding
# INFO:root:Round 47:Pareto update
# INFO:root:Round 47:Useful update
# INFO:root:Round 47:There are 169 designs left in set S and 0 designs in set P.
# INFO:root:Round 47:Sample count 47
# INFO:root:Round 48:Evaluating
# INFO:root:Round 48:Modeling
# INFO:root:Round 48:Discarding
# INFO:root:Round 48:Pareto update
# INFO:root:Round 48:Useful update
# INFO:root:Round 48:There are 168 designs left in set S and 0 designs in set P.
# INFO:root:Round 48:Sample count 48
# INFO:root:Round 49:Evaluating
# INFO:root:Round 49:Modeling
# INFO:root:Round 49:Discarding
# INFO:root:Round 49:Pareto update
# INFO:root:Round 49:Useful update
# INFO:root:Round 49:There are 168 designs left in set S and 0 designs in set P.
# INFO:root:Round 49:Sample count 49
# INFO:root:Round 50:Evaluating
# INFO:root:Round 50:Modeling
# INFO:root:Round 50:Discarding
# INFO:root:Round 50:Pareto update
# INFO:root:Round 50:Useful update
# INFO:root:Round 50:There are 168 designs left in set S and 0 designs in set P.
# INFO:root:Round 50:Sample count 50
# INFO:root:Round 51:Evaluating
# INFO:root:Round 51:Modeling
# INFO:root:Round 51:Discarding
# INFO:root:Round 51:Pareto update
# INFO:root:Round 51:Useful update
# INFO:root:Round 51:There are 167 designs left in set S and 0 designs in set P.
# INFO:root:Round 51:Sample count 51
# INFO:root:Round 52:Evaluating
# INFO:root:Round 52:Modeling
# INFO:root:Round 52:Discarding
# INFO:root:Round 52:Pareto update
# INFO:root:Round 52:Useful update
# INFO:root:Round 52:There are 166 designs left in set S and 0 designs in set P.
# INFO:root:Round 52:Sample count 52
# INFO:root:Round 53:Evaluating
# INFO:root:Round 53:Modeling
# INFO:root:Round 53:Discarding
# INFO:root:Round 53:Pareto update
# INFO:root:Round 53:Useful update
# INFO:root:Round 53:There are 166 designs left in set S and 0 designs in set P.
# INFO:root:Round 53:Sample count 53
# INFO:root:Round 54:Evaluating
# INFO:root:Round 54:Modeling
# INFO:root:Round 54:Discarding
# INFO:root:Round 54:Pareto update
# INFO:root:Round 54:Useful update
# INFO:root:Round 54:There are 165 designs left in set S and 0 designs in set P.
# INFO:root:Round 54:Sample count 54
# INFO:root:Round 55:Evaluating
# INFO:root:Round 55:Modeling
# INFO:root:Round 55:Discarding
# INFO:root:Round 55:Pareto update
# INFO:root:Round 55:Useful update
# INFO:root:Round 55:There are 164 designs left in set S and 0 designs in set P.
# INFO:root:Round 55:Sample count 55
# INFO:root:Round 56:Evaluating
# INFO:root:Round 56:Modeling
# INFO:root:Round 56:Discarding
# INFO:root:Round 56:Pareto update
# INFO:root:Round 56:Useful update
# INFO:root:Round 56:There are 164 designs left in set S and 0 designs in set P.
# INFO:root:Round 56:Sample count 56
# INFO:root:Round 57:Evaluating
# INFO:root:Round 57:Modeling
# INFO:root:Round 57:Discarding
# INFO:root:Round 57:Pareto update
# INFO:root:Round 57:Useful update
# INFO:root:Round 57:There are 163 designs left in set S and 0 designs in set P.
# INFO:root:Round 57:Sample count 57
# INFO:root:Round 58:Evaluating
# INFO:root:Round 58:Modeling
# INFO:root:Round 58:Discarding
# INFO:root:Round 58:Pareto update
# INFO:root:Round 58:Useful update
# INFO:root:Round 58:There are 162 designs left in set S and 0 designs in set P.
# INFO:root:Round 58:Sample count 58
# INFO:root:Round 59:Evaluating
# INFO:root:Round 59:Modeling
# INFO:root:Round 59:Discarding
# INFO:root:Round 59:Pareto update
# INFO:root:Round 59:Useful update
# INFO:root:Round 59:There are 162 designs left in set S and 0 designs in set P.
# INFO:root:Round 59:Sample count 59
# INFO:root:Round 60:Evaluating
# INFO:root:Round 60:Modeling
# INFO:root:Round 60:Discarding
# INFO:root:Round 60:Pareto update
# INFO:root:Round 60:Useful update
# INFO:root:Round 60:There are 161 designs left in set S and 0 designs in set P.
# INFO:root:Round 60:Sample count 60
# INFO:root:Round 61:Evaluating
# INFO:root:Round 61:Modeling
# INFO:root:Round 61:Discarding
# INFO:root:Round 61:Pareto update
# INFO:root:Round 61:Useful update
# INFO:root:Round 61:There are 160 designs left in set S and 0 designs in set P.
# INFO:root:Round 61:Sample count 61
# INFO:root:Round 62:Evaluating
# INFO:root:Round 62:Modeling
# INFO:root:Round 62:Discarding
# INFO:root:Round 62:Pareto update
# INFO:root:Round 62:Useful update
# INFO:root:Round 62:There are 159 designs left in set S and 0 designs in set P.
# INFO:root:Round 62:Sample count 62
# INFO:root:Round 63:Evaluating
# INFO:root:Round 63:Modeling
# INFO:root:Round 63:Discarding
# INFO:root:Round 63:Pareto update
# INFO:root:Round 63:Useful update
# INFO:root:Round 63:There are 158 designs left in set S and 0 designs in set P.
# INFO:root:Round 63:Sample count 63
# INFO:root:Round 64:Evaluating
# INFO:root:Round 64:Modeling
# INFO:root:Round 64:Discarding
# INFO:root:Round 64:Pareto update
# INFO:root:Round 64:Useful update
# INFO:root:Round 64:There are 157 designs left in set S and 0 designs in set P.
# INFO:root:Round 64:Sample count 64
# INFO:root:Round 65:Evaluating
# INFO:root:Round 65:Modeling
# INFO:root:Round 65:Discarding
# INFO:root:Round 65:Pareto update
# INFO:root:Round 65:Useful update
# INFO:root:Round 65:There are 156 designs left in set S and 0 designs in set P.
# INFO:root:Round 65:Sample count 65
# INFO:root:Round 66:Evaluating
# INFO:root:Round 66:Modeling
# INFO:root:Round 66:Discarding
# INFO:root:Round 66:Pareto update
# INFO:root:Round 66:Useful update
# INFO:root:Round 66:There are 155 designs left in set S and 0 designs in set P.
# INFO:root:Round 66:Sample count 66
# INFO:root:Round 67:Evaluating
# INFO:root:Round 67:Modeling
# INFO:root:Round 67:Discarding
# INFO:root:Round 67:Pareto update
# INFO:root:Round 67:Useful update
# INFO:root:Round 67:There are 154 designs left in set S and 0 designs in set P.
# INFO:root:Round 67:Sample count 67
# INFO:root:Round 68:Evaluating
# INFO:root:Round 68:Modeling
# INFO:root:Round 68:Discarding
# INFO:root:Round 68:Pareto update
# INFO:root:Round 68:Useful update
# INFO:root:Round 68:There are 154 designs left in set S and 0 designs in set P.
# INFO:root:Round 68:Sample count 68
# INFO:root:Round 69:Evaluating
# INFO:root:Round 69:Modeling
# INFO:root:Round 69:Discarding
# INFO:root:Round 69:Pareto update
# INFO:root:Round 69:Useful update
# INFO:root:Round 69:There are 153 designs left in set S and 0 designs in set P.
# INFO:root:Round 69:Sample count 69
# INFO:root:Round 70:Evaluating
# INFO:root:Round 70:Modeling
# INFO:root:Round 70:Discarding
# INFO:root:Round 70:Pareto update
# INFO:root:Round 70:Useful update
# INFO:root:Round 70:There are 152 designs left in set S and 0 designs in set P.
# INFO:root:Round 70:Sample count 70
# INFO:root:Round 71:Evaluating
# INFO:root:Round 71:Modeling
# INFO:root:Round 71:Discarding
# INFO:root:Round 71:Pareto update
# INFO:root:Round 71:Useful update
# INFO:root:Round 71:There are 152 designs left in set S and 0 designs in set P.
# INFO:root:Round 71:Sample count 71
# INFO:root:Round 72:Evaluating
# INFO:root:Round 72:Modeling
# INFO:root:Round 72:Discarding
# INFO:root:Round 72:Pareto update
# INFO:root:Round 72:Useful update
# INFO:root:Round 72:There are 151 designs left in set S and 0 designs in set P.
# INFO:root:Round 72:Sample count 72
# INFO:root:Round 73:Evaluating
# INFO:root:Round 73:Modeling
# INFO:root:Round 73:Discarding
# INFO:root:Round 73:Pareto update
# INFO:root:Round 73:Useful update
# INFO:root:Round 73:There are 151 designs left in set S and 0 designs in set P.
# INFO:root:Round 73:Sample count 73
# INFO:root:Round 74:Evaluating
# INFO:root:Round 74:Modeling
# INFO:root:Round 74:Discarding
# INFO:root:Round 74:Pareto update
# INFO:root:Round 74:Useful update
# INFO:root:Round 74:There are 151 designs left in set S and 0 designs in set P.
# INFO:root:Round 74:Sample count 74
# INFO:root:Round 75:Evaluating
# INFO:root:Round 75:Modeling
# INFO:root:Round 75:Discarding
# INFO:root:Round 75:Pareto update
# INFO:root:Round 75:Useful update
# INFO:root:Round 75:There are 151 designs left in set S and 0 designs in set P.
# INFO:root:Round 75:Sample count 75
# INFO:root:Round 76:Evaluating
# INFO:root:Round 76:Modeling
# INFO:root:Round 76:Discarding
# INFO:root:Round 76:Pareto update
# INFO:root:Round 76:Useful update
# INFO:root:Round 76:There are 150 designs left in set S and 0 designs in set P.
# INFO:root:Round 76:Sample count 76
# INFO:root:Round 77:Evaluating
# INFO:root:Round 77:Modeling
# INFO:root:Round 77:Discarding
# INFO:root:Round 77:Pareto update
# INFO:root:Round 77:Useful update
# INFO:root:Round 77:There are 150 designs left in set S and 0 designs in set P.
# INFO:root:Round 77:Sample count 77
# INFO:root:Round 78:Evaluating
# INFO:root:Round 78:Modeling
# INFO:root:Round 78:Discarding
# INFO:root:Round 78:Pareto update
# INFO:root:Round 78:Useful update
# INFO:root:Round 78:There are 150 designs left in set S and 0 designs in set P.
# INFO:root:Round 78:Sample count 78
# INFO:root:Round 79:Evaluating
# INFO:root:Round 79:Modeling
# INFO:root:Round 79:Discarding
# INFO:root:Round 79:Pareto update
# INFO:root:Round 79:Useful update
# INFO:root:Round 79:There are 149 designs left in set S and 0 designs in set P.
# INFO:root:Round 79:Sample count 79
# INFO:root:Round 80:Evaluating
# INFO:root:Round 80:Modeling
# INFO:root:Round 80:Discarding
# INFO:root:Round 80:Pareto update
# INFO:root:Round 80:Useful update
# INFO:root:Round 80:There are 149 designs left in set S and 0 designs in set P.
# INFO:root:Round 80:Sample count 80
# INFO:root:Round 81:Evaluating
# INFO:root:Round 81:Modeling
# INFO:root:Round 81:Discarding
# INFO:root:Round 81:Pareto update
# INFO:root:Round 81:Useful update
# INFO:root:Round 81:There are 149 designs left in set S and 0 designs in set P.
# INFO:root:Round 81:Sample count 81
# INFO:root:Round 82:Evaluating
# INFO:root:Round 82:Modeling
# INFO:root:Round 82:Discarding
# INFO:root:Round 82:Pareto update
# INFO:root:Round 82:Useful update
# INFO:root:Round 82:There are 148 designs left in set S and 0 designs in set P.
# INFO:root:Round 82:Sample count 82
# INFO:root:Round 83:Evaluating
# INFO:root:Round 83:Modeling
# INFO:root:Round 83:Discarding
# INFO:root:Round 83:Pareto update
# INFO:root:Round 83:Useful update
# INFO:root:Round 83:There are 148 designs left in set S and 0 designs in set P.
# INFO:root:Round 83:Sample count 83
# INFO:root:Round 84:Evaluating
# INFO:root:Round 84:Modeling
# INFO:root:Round 84:Discarding
# INFO:root:Round 84:Pareto update
# INFO:root:Round 84:Useful update
# INFO:root:Round 84:There are 147 designs left in set S and 0 designs in set P.
# INFO:root:Round 84:Sample count 84
# INFO:root:Round 85:Evaluating
# INFO:root:Round 85:Modeling
# INFO:root:Round 85:Discarding
# INFO:root:Round 85:Pareto update
# INFO:root:Round 85:Useful update
# INFO:root:Round 85:There are 146 designs left in set S and 0 designs in set P.
# INFO:root:Round 85:Sample count 85
# INFO:root:Round 86:Evaluating
# INFO:root:Round 86:Modeling
# INFO:root:Round 86:Discarding
# INFO:root:Round 86:Pareto update
# INFO:root:Round 86:Useful update
# INFO:root:Round 86:There are 146 designs left in set S and 0 designs in set P.
# INFO:root:Round 86:Sample count 86
# INFO:root:Round 87:Evaluating
# INFO:root:Round 87:Modeling
# INFO:root:Round 87:Discarding
# INFO:root:Round 87:Pareto update
# INFO:root:Round 87:Useful update
# INFO:root:Round 87:There are 146 designs left in set S and 0 designs in set P.
# INFO:root:Round 87:Sample count 87
# INFO:root:Round 88:Evaluating
# INFO:root:Round 88:Modeling
# INFO:root:Round 88:Discarding
# INFO:root:Round 88:Pareto update
# INFO:root:Round 88:Useful update
# INFO:root:Round 88:There are 145 designs left in set S and 0 designs in set P.
# INFO:root:Round 88:Sample count 88
# INFO:root:Round 89:Evaluating
# INFO:root:Round 89:Modeling
# INFO:root:Round 89:Discarding
# INFO:root:Round 89:Pareto update
# INFO:root:Round 89:Useful update
# INFO:root:Round 89:There are 144 designs left in set S and 0 designs in set P.
# INFO:root:Round 89:Sample count 89
# INFO:root:Round 90:Evaluating
# INFO:root:Round 90:Modeling
# INFO:root:Round 90:Discarding
# INFO:root:Round 90:Pareto update
# INFO:root:Round 90:Useful update
# INFO:root:Round 90:There are 143 designs left in set S and 0 designs in set P.
# INFO:root:Round 90:Sample count 90
# INFO:root:Round 91:Evaluating
# INFO:root:Round 91:Modeling
# INFO:root:Round 91:Discarding
# INFO:root:Round 91:Pareto update
# INFO:root:Round 91:Useful update
# INFO:root:Round 91:There are 143 designs left in set S and 0 designs in set P.
# INFO:root:Round 91:Sample count 91
# INFO:root:Round 92:Evaluating
# INFO:root:Round 92:Modeling
# INFO:root:Round 92:Discarding
# INFO:root:Round 92:Pareto update
# INFO:root:Round 92:Useful update
# INFO:root:Round 92:There are 143 designs left in set S and 0 designs in set P.
# INFO:root:Round 92:Sample count 92
# INFO:root:Round 93:Evaluating
# INFO:root:Round 93:Modeling
# INFO:root:Round 93:Discarding
# INFO:root:Round 93:Pareto update
# INFO:root:Round 93:Useful update
# INFO:root:Round 93:There are 142 designs left in set S and 0 designs in set P.
# INFO:root:Round 93:Sample count 93
# INFO:root:Round 94:Evaluating
# INFO:root:Round 94:Modeling
# INFO:root:Round 94:Discarding
# INFO:root:Round 94:Pareto update
# INFO:root:Round 94:Useful update
# INFO:root:Round 94:There are 141 designs left in set S and 0 designs in set P.
# INFO:root:Round 94:Sample count 94
# INFO:root:Round 95:Evaluating
# INFO:root:Round 95:Modeling
# INFO:root:Round 95:Discarding
# INFO:root:Round 95:Pareto update
# INFO:root:Round 95:Useful update
# INFO:root:Round 95:There are 141 designs left in set S and 0 designs in set P.
# INFO:root:Round 95:Sample count 95
# INFO:root:Round 96:Evaluating
# INFO:root:Round 96:Modeling
# INFO:root:Round 96:Discarding
# INFO:root:Round 96:Pareto update
# INFO:root:Round 96:Useful update
# INFO:root:Round 96:There are 141 designs left in set S and 0 designs in set P.
# INFO:root:Round 96:Sample count 96
# INFO:root:Round 97:Evaluating
# INFO:root:Round 97:Modeling
# INFO:root:Round 97:Discarding
# INFO:root:Round 97:Pareto update
# INFO:root:Round 97:Useful update
# INFO:root:Round 97:There are 140 designs left in set S and 0 designs in set P.
# INFO:root:Round 97:Sample count 97
# INFO:root:Round 98:Evaluating
# INFO:root:Round 98:Modeling
# INFO:root:Round 98:Discarding
# INFO:root:Round 98:Pareto update
# INFO:root:Round 98:Useful update
# INFO:root:Round 98:There are 139 designs left in set S and 0 designs in set P.
# INFO:root:Round 98:Sample count 98
# INFO:root:Round 99:Evaluating
# INFO:root:Round 99:Modeling
# INFO:root:Round 99:Discarding
# INFO:root:Round 99:Pareto update
# INFO:root:Round 99:Useful update
# INFO:root:Round 99:There are 138 designs left in set S and 0 designs in set P.
# INFO:root:Round 99:Sample count 99
# INFO:root:Round 100:Evaluating
# INFO:root:Round 100:Modeling
# INFO:root:Round 100:Discarding
# INFO:root:Round 100:Pareto update
# INFO:root:Round 100:Useful update
# INFO:root:Round 100:There are 138 designs left in set S and 0 designs in set P.
# INFO:root:Round 100:Sample count 100
# INFO:root:Round 101:Evaluating
# INFO:root:Round 101:Modeling
# INFO:root:Round 101:Discarding
# INFO:root:Round 101:Pareto update
# INFO:root:Round 101:Useful update
# INFO:root:Round 101:There are 138 designs left in set S and 0 designs in set P.
# INFO:root:Round 101:Sample count 101
# INFO:root:Round 102:Evaluating
# INFO:root:Round 102:Modeling
# INFO:root:Round 102:Discarding
# INFO:root:Round 102:Pareto update
# INFO:root:Round 102:Useful update
# INFO:root:Round 102:There are 138 designs left in set S and 0 designs in set P.
# INFO:root:Round 102:Sample count 102
# INFO:root:Round 103:Evaluating
# INFO:root:Round 103:Modeling
# INFO:root:Round 103:Discarding
# INFO:root:Round 103:Pareto update
# INFO:root:Round 103:Useful update
# INFO:root:Round 103:There are 137 designs left in set S and 0 designs in set P.
# INFO:root:Round 103:Sample count 103
# INFO:root:Round 104:Evaluating
# INFO:root:Round 104:Modeling
# INFO:root:Round 104:Discarding
# INFO:root:Round 104:Pareto update
# INFO:root:Round 104:Useful update
# INFO:root:Round 104:There are 136 designs left in set S and 0 designs in set P.
# INFO:root:Round 104:Sample count 104
# INFO:root:Round 105:Evaluating
# INFO:root:Round 105:Modeling
# INFO:root:Round 105:Discarding
# INFO:root:Round 105:Pareto update
# INFO:root:Round 105:Useful update
# INFO:root:Round 105:There are 136 designs left in set S and 0 designs in set P.
# INFO:root:Round 105:Sample count 105
# INFO:root:Round 106:Evaluating
# INFO:root:Round 106:Modeling
# INFO:root:Round 106:Discarding
# INFO:root:Round 106:Pareto update
# INFO:root:Round 106:Useful update
# INFO:root:Round 106:There are 136 designs left in set S and 0 designs in set P.
# INFO:root:Round 106:Sample count 106
# INFO:root:Round 107:Evaluating
# INFO:root:Round 107:Modeling
# INFO:root:Round 107:Discarding
# INFO:root:Round 107:Pareto update
# INFO:root:Round 107:Useful update
# INFO:root:Round 107:There are 135 designs left in set S and 0 designs in set P.
# INFO:root:Round 107:Sample count 107
# INFO:root:Round 108:Evaluating
# INFO:root:Round 108:Modeling
# INFO:root:Round 108:Discarding
# INFO:root:Round 108:Pareto update
# INFO:root:Round 108:Useful update
# INFO:root:Round 108:There are 135 designs left in set S and 0 designs in set P.
# INFO:root:Round 108:Sample count 108
# INFO:root:Round 109:Evaluating
# INFO:root:Round 109:Modeling
# INFO:root:Round 109:Discarding
# INFO:root:Round 109:Pareto update
# INFO:root:Round 109:Useful update
# INFO:root:Round 109:There are 135 designs left in set S and 0 designs in set P.
# INFO:root:Round 109:Sample count 109
# INFO:root:Round 110:Evaluating
# INFO:root:Round 110:Modeling
# INFO:root:Round 110:Discarding
# INFO:root:Round 110:Pareto update
# INFO:root:Round 110:Useful update
# INFO:root:Round 110:There are 134 designs left in set S and 0 designs in set P.
# INFO:root:Round 110:Sample count 110
# INFO:root:Round 111:Evaluating
# INFO:root:Round 111:Modeling
# INFO:root:Round 111:Discarding
# INFO:root:Round 111:Pareto update
# INFO:root:Round 111:Useful update
# INFO:root:Round 111:There are 134 designs left in set S and 0 designs in set P.
# INFO:root:Round 111:Sample count 111
# INFO:root:Round 112:Evaluating
# INFO:root:Round 112:Modeling
# INFO:root:Round 112:Discarding
# INFO:root:Round 112:Pareto update
# INFO:root:Round 112:Useful update
# INFO:root:Round 112:There are 134 designs left in set S and 0 designs in set P.
# INFO:root:Round 112:Sample count 112
# INFO:root:Round 113:Evaluating
# INFO:root:Round 113:Modeling
# INFO:root:Round 113:Discarding
# INFO:root:Round 113:Pareto update
# INFO:root:Round 113:Useful update
# INFO:root:Round 113:There are 133 designs left in set S and 0 designs in set P.
# INFO:root:Round 113:Sample count 113
# INFO:root:Round 114:Evaluating
# INFO:root:Round 114:Modeling
# INFO:root:Round 114:Discarding
# INFO:root:Round 114:Pareto update
# INFO:root:Round 114:Useful update
# INFO:root:Round 114:There are 132 designs left in set S and 0 designs in set P.
# INFO:root:Round 114:Sample count 114
# INFO:root:Round 115:Evaluating
# INFO:root:Round 115:Modeling
# INFO:root:Round 115:Discarding
# INFO:root:Round 115:Pareto update
# INFO:root:Round 115:Useful update
# INFO:root:Round 115:There are 131 designs left in set S and 0 designs in set P.
# INFO:root:Round 115:Sample count 115
# INFO:root:Round 116:Evaluating
# INFO:root:Round 116:Modeling
# INFO:root:Round 116:Discarding
# INFO:root:Round 116:Pareto update
# INFO:root:Round 116:Useful update
# INFO:root:Round 116:There are 131 designs left in set S and 0 designs in set P.
# INFO:root:Round 116:Sample count 116
# INFO:root:Round 117:Evaluating
# INFO:root:Round 117:Modeling
# INFO:root:Round 117:Discarding
# INFO:root:Round 117:Pareto update
# INFO:root:Round 117:Useful update
# INFO:root:Round 117:There are 130 designs left in set S and 0 designs in set P.
# INFO:root:Round 117:Sample count 117
# INFO:root:Round 118:Evaluating
# INFO:root:Round 118:Modeling
# INFO:root:Round 118:Discarding
# INFO:root:Round 118:Pareto update
# INFO:root:Round 118:Useful update
# INFO:root:Round 118:There are 129 designs left in set S and 0 designs in set P.
# INFO:root:Round 118:Sample count 118
# INFO:root:Round 119:Evaluating
# INFO:root:Round 119:Modeling
# INFO:root:Round 119:Discarding
# INFO:root:Round 119:Pareto update
# INFO:root:Round 119:Useful update
# INFO:root:Round 119:There are 128 designs left in set S and 0 designs in set P.
# INFO:root:Round 119:Sample count 119
# INFO:root:Round 120:Evaluating
# INFO:root:Round 120:Modeling
# INFO:root:Round 120:Discarding
# INFO:root:Round 120:Pareto update
# INFO:root:Round 120:Useful update
# INFO:root:Round 120:There are 127 designs left in set S and 0 designs in set P.
# INFO:root:Round 120:Sample count 120
# INFO:root:Round 121:Evaluating
# INFO:root:Round 121:Modeling
# INFO:root:Round 121:Discarding
# INFO:root:Round 121:Pareto update
# INFO:root:Round 121:Useful update
# INFO:root:Round 121:There are 127 designs left in set S and 0 designs in set P.
# INFO:root:Round 121:Sample count 121
# INFO:root:Round 122:Evaluating
# INFO:root:Round 122:Modeling
# INFO:root:Round 122:Discarding
# INFO:root:Round 122:Pareto update
# INFO:root:Round 122:Useful update
# INFO:root:Round 122:There are 126 designs left in set S and 0 designs in set P.
# INFO:root:Round 122:Sample count 122
# INFO:root:Round 123:Evaluating
# INFO:root:Round 123:Modeling
# INFO:root:Round 123:Discarding
# INFO:root:Round 123:Pareto update
# INFO:root:Round 123:Useful update
# INFO:root:Round 123:There are 126 designs left in set S and 0 designs in set P.
# INFO:root:Round 123:Sample count 123
# INFO:root:Round 124:Evaluating
# INFO:root:Round 124:Modeling
# INFO:root:Round 124:Discarding
# INFO:root:Round 124:Pareto update
# INFO:root:Round 124:Useful update
# INFO:root:Round 124:There are 126 designs left in set S and 0 designs in set P.
# INFO:root:Round 124:Sample count 124
# INFO:root:Round 125:Evaluating
# INFO:root:Round 125:Modeling
# INFO:root:Round 125:Discarding
# INFO:root:Round 125:Pareto update
# INFO:root:Round 125:Useful update
# INFO:root:Round 125:There are 126 designs left in set S and 0 designs in set P.
# INFO:root:Round 125:Sample count 125
# INFO:root:Round 126:Evaluating
# INFO:root:Round 126:Modeling
# INFO:root:Round 126:Discarding
# INFO:root:Round 126:Pareto update
# INFO:root:Round 126:Useful update
# INFO:root:Round 126:There are 125 designs left in set S and 0 designs in set P.
# INFO:root:Round 126:Sample count 126
# INFO:root:Round 127:Evaluating
# INFO:root:Round 127:Modeling
# INFO:root:Round 127:Discarding
# INFO:root:Round 127:Pareto update
# INFO:root:Round 127:Useful update
# INFO:root:Round 127:There are 124 designs left in set S and 0 designs in set P.
# INFO:root:Round 127:Sample count 127
# INFO:root:Round 128:Evaluating
# INFO:root:Round 128:Modeling
# INFO:root:Round 128:Discarding
# INFO:root:Round 128:Pareto update
# INFO:root:Round 128:Useful update
# INFO:root:Round 128:There are 124 designs left in set S and 0 designs in set P.
# INFO:root:Round 128:Sample count 128
# INFO:root:Round 129:Evaluating
# INFO:root:Round 129:Modeling
# INFO:root:Round 129:Discarding
# INFO:root:Round 129:Pareto update
# INFO:root:Round 129:Useful update
# INFO:root:Round 129:There are 124 designs left in set S and 0 designs in set P.
# INFO:root:Round 129:Sample count 129
# INFO:root:Round 130:Evaluating
# INFO:root:Round 130:Modeling
# INFO:root:Round 130:Discarding
# INFO:root:Round 130:Pareto update
# INFO:root:Round 130:Useful update
# INFO:root:Round 130:There are 123 designs left in set S and 0 designs in set P.
# INFO:root:Round 130:Sample count 130
# INFO:root:Round 131:Evaluating
# INFO:root:Round 131:Modeling
# INFO:root:Round 131:Discarding
# INFO:root:Round 131:Pareto update
# INFO:root:Round 131:Useful update
# INFO:root:Round 131:There are 123 designs left in set S and 0 designs in set P.
# INFO:root:Round 131:Sample count 131
# INFO:root:Round 132:Evaluating
# INFO:root:Round 132:Modeling
# INFO:root:Round 132:Discarding
# INFO:root:Round 132:Pareto update
# INFO:root:Round 132:Useful update
# INFO:root:Round 132:There are 123 designs left in set S and 0 designs in set P.
# INFO:root:Round 132:Sample count 132
# INFO:root:Round 133:Evaluating
# INFO:root:Round 133:Modeling
# INFO:root:Round 133:Discarding
# INFO:root:Round 133:Pareto update
# INFO:root:Round 133:Useful update
# INFO:root:Round 133:There are 122 designs left in set S and 0 designs in set P.
# INFO:root:Round 133:Sample count 133
# INFO:root:Round 134:Evaluating
# INFO:root:Round 134:Modeling
# INFO:root:Round 134:Discarding
# INFO:root:Round 134:Pareto update
# INFO:root:Round 134:Useful update
# INFO:root:Round 134:There are 121 designs left in set S and 0 designs in set P.
# INFO:root:Round 134:Sample count 134
# INFO:root:Round 135:Evaluating
# INFO:root:Round 135:Modeling
# INFO:root:Round 135:Discarding
# INFO:root:Round 135:Pareto update
# INFO:root:Round 135:Useful update
# INFO:root:Round 135:There are 120 designs left in set S and 0 designs in set P.
# INFO:root:Round 135:Sample count 135
# INFO:root:Round 136:Evaluating
# INFO:root:Round 136:Modeling
# INFO:root:Round 136:Discarding
# INFO:root:Round 136:Pareto update
# INFO:root:Round 136:Useful update
# INFO:root:Round 136:There are 119 designs left in set S and 0 designs in set P.
# INFO:root:Round 136:Sample count 136
# INFO:root:Round 137:Evaluating
# INFO:root:Round 137:Modeling
# INFO:root:Round 137:Discarding
# INFO:root:Round 137:Pareto update
# INFO:root:Round 137:Useful update
# INFO:root:Round 137:There are 119 designs left in set S and 0 designs in set P.
# INFO:root:Round 137:Sample count 137
# INFO:root:Round 138:Evaluating
# INFO:root:Round 138:Modeling
# INFO:root:Round 138:Discarding
# INFO:root:Round 138:Pareto update
# INFO:root:Round 138:Useful update
# INFO:root:Round 138:There are 119 designs left in set S and 0 designs in set P.
# INFO:root:Round 138:Sample count 138
# INFO:root:Round 139:Evaluating
# INFO:root:Round 139:Modeling
# INFO:root:Round 139:Discarding
# INFO:root:Round 139:Pareto update
# INFO:root:Round 139:Useful update
# INFO:root:Round 139:There are 119 designs left in set S and 0 designs in set P.
# INFO:root:Round 139:Sample count 139
# INFO:root:Round 140:Evaluating
# INFO:root:Round 140:Modeling
# INFO:root:Round 140:Discarding
# INFO:root:Round 140:Pareto update
# INFO:root:Round 140:Useful update
# INFO:root:Round 140:There are 118 designs left in set S and 0 designs in set P.
# INFO:root:Round 140:Sample count 140
# INFO:root:Round 141:Evaluating
# INFO:root:Round 141:Modeling
# INFO:root:Round 141:Discarding
# INFO:root:Round 141:Pareto update
# INFO:root:Round 141:Useful update
# INFO:root:Round 141:There are 117 designs left in set S and 0 designs in set P.
# INFO:root:Round 141:Sample count 141
# INFO:root:Round 142:Evaluating
# INFO:root:Round 142:Modeling
# INFO:root:Round 142:Discarding
# INFO:root:Round 142:Pareto update
# INFO:root:Round 142:Useful update
# INFO:root:Round 142:There are 116 designs left in set S and 0 designs in set P.
# INFO:root:Round 142:Sample count 142
# INFO:root:Round 143:Evaluating
# INFO:root:Round 143:Modeling
# INFO:root:Round 143:Discarding
# INFO:root:Round 143:Pareto update
# INFO:root:Round 143:Useful update
# INFO:root:Round 143:There are 115 designs left in set S and 0 designs in set P.
# INFO:root:Round 143:Sample count 143
# INFO:root:Round 144:Evaluating
# INFO:root:Round 144:Modeling
# INFO:root:Round 144:Discarding
# INFO:root:Round 144:Pareto update
# INFO:root:Round 144:Useful update
# INFO:root:Round 144:There are 114 designs left in set S and 0 designs in set P.
# INFO:root:Round 144:Sample count 144
# INFO:root:Round 145:Evaluating
# INFO:root:Round 145:Modeling
# INFO:root:Round 145:Discarding
# INFO:root:Round 145:Pareto update
# INFO:root:Round 145:Useful update
# INFO:root:Round 145:There are 113 designs left in set S and 0 designs in set P.
# INFO:root:Round 145:Sample count 145
# INFO:root:Round 146:Evaluating
# INFO:root:Round 146:Modeling
# INFO:root:Round 146:Discarding
# INFO:root:Round 146:Pareto update
# INFO:root:Round 146:Useful update
# INFO:root:Round 146:There are 113 designs left in set S and 0 designs in set P.
# INFO:root:Round 146:Sample count 146
# INFO:root:Round 147:Evaluating
# INFO:root:Round 147:Modeling
# INFO:root:Round 147:Discarding
# INFO:root:Round 147:Pareto update
# INFO:root:Round 147:Useful update
# INFO:root:Round 147:There are 113 designs left in set S and 0 designs in set P.
# INFO:root:Round 147:Sample count 147
# INFO:root:Round 148:Evaluating
# INFO:root:Round 148:Modeling
# INFO:root:Round 148:Discarding
# INFO:root:Round 148:Pareto update
# INFO:root:Round 148:Useful update
# INFO:root:Round 148:There are 112 designs left in set S and 0 designs in set P.
# INFO:root:Round 148:Sample count 148
# INFO:root:Round 149:Evaluating
# INFO:root:Round 149:Modeling
# INFO:root:Round 149:Discarding
# INFO:root:Round 149:Pareto update
# INFO:root:Round 149:Useful update
# INFO:root:Round 149:There are 111 designs left in set S and 0 designs in set P.
# INFO:root:Round 149:Sample count 149
# INFO:root:Round 150:Evaluating
# INFO:root:Round 150:Modeling
# INFO:root:Round 150:Discarding
# INFO:root:Round 150:Pareto update
# INFO:root:Round 150:Useful update
# INFO:root:Round 150:There are 111 designs left in set S and 0 designs in set P.
# INFO:root:Round 150:Sample count 150
# INFO:root:Round 151:Evaluating
# INFO:root:Round 151:Modeling
# INFO:root:Round 151:Discarding
# INFO:root:Round 151:Pareto update
# INFO:root:Round 151:Useful update
# INFO:root:Round 151:There are 111 designs left in set S and 0 designs in set P.
# INFO:root:Round 151:Sample count 151
# INFO:root:Round 152:Evaluating
# INFO:root:Round 152:Modeling
# INFO:root:Round 152:Discarding
# INFO:root:Round 152:Pareto update
# INFO:root:Round 152:Useful update
# INFO:root:Round 152:There are 110 designs left in set S and 0 designs in set P.
# INFO:root:Round 152:Sample count 152
# INFO:root:Round 153:Evaluating
# INFO:root:Round 153:Modeling
# INFO:root:Round 153:Discarding
# INFO:root:Round 153:Pareto update
# INFO:root:Round 153:Useful update
# INFO:root:Round 153:There are 109 designs left in set S and 0 designs in set P.
# INFO:root:Round 153:Sample count 153
# INFO:root:Round 154:Evaluating
# INFO:root:Round 154:Modeling
# INFO:root:Round 154:Discarding
# INFO:root:Round 154:Pareto update
# INFO:root:Round 154:Useful update
# INFO:root:Round 154:There are 108 designs left in set S and 0 designs in set P.
# INFO:root:Round 154:Sample count 154
# INFO:root:Round 155:Evaluating
# INFO:root:Round 155:Modeling
# INFO:root:Round 155:Discarding
# INFO:root:Round 155:Pareto update
# INFO:root:Round 155:Useful update
# INFO:root:Round 155:There are 107 designs left in set S and 0 designs in set P.
# INFO:root:Round 155:Sample count 155
# INFO:root:Round 156:Evaluating
# INFO:root:Round 156:Modeling
# INFO:root:Round 156:Discarding
# INFO:root:Round 156:Pareto update
# INFO:root:Round 156:Useful update
# INFO:root:Round 156:There are 106 designs left in set S and 0 designs in set P.
# INFO:root:Round 156:Sample count 156
# INFO:root:Round 157:Evaluating
# INFO:root:Round 157:Modeling
# INFO:root:Round 157:Discarding
# INFO:root:Round 157:Pareto update
# INFO:root:Round 157:Useful update
# INFO:root:Round 157:There are 105 designs left in set S and 0 designs in set P.
# INFO:root:Round 157:Sample count 157
# INFO:root:Round 158:Evaluating
# INFO:root:Round 158:Modeling
# INFO:root:Round 158:Discarding
# INFO:root:Round 158:Pareto update
# INFO:root:Round 158:Useful update
# INFO:root:Round 158:There are 105 designs left in set S and 0 designs in set P.
# INFO:root:Round 158:Sample count 158
# INFO:root:Round 159:Evaluating
# INFO:root:Round 159:Modeling
# INFO:root:Round 159:Discarding
# INFO:root:Round 159:Pareto update
# INFO:root:Round 159:Useful update
# INFO:root:Round 159:There are 104 designs left in set S and 0 designs in set P.
# INFO:root:Round 159:Sample count 159
# INFO:root:Round 160:Evaluating
# INFO:root:Round 160:Modeling
# INFO:root:Round 160:Discarding
# INFO:root:Round 160:Pareto update
# INFO:root:Round 160:Useful update
# INFO:root:Round 160:There are 103 designs left in set S and 0 designs in set P.
# INFO:root:Round 160:Sample count 160
# INFO:root:Round 161:Evaluating
# INFO:root:Round 161:Modeling
# INFO:root:Round 161:Discarding
# INFO:root:Round 161:Pareto update
# INFO:root:Round 161:Useful update
# INFO:root:Round 161:There are 102 designs left in set S and 0 designs in set P.
# INFO:root:Round 161:Sample count 161
# INFO:root:Round 162:Evaluating
# INFO:root:Round 162:Modeling
# INFO:root:Round 162:Discarding
# INFO:root:Round 162:Pareto update
# INFO:root:Round 162:Useful update
# INFO:root:Round 162:There are 101 designs left in set S and 0 designs in set P.
# INFO:root:Round 162:Sample count 162
# INFO:root:Round 163:Evaluating
# INFO:root:Round 163:Modeling
# INFO:root:Round 163:Discarding
# INFO:root:Round 163:Pareto update
# INFO:root:Round 163:Useful update
# INFO:root:Round 163:There are 100 designs left in set S and 0 designs in set P.
# INFO:root:Round 163:Sample count 163
# INFO:root:Round 164:Evaluating
# INFO:root:Round 164:Modeling
# INFO:root:Round 164:Discarding
# INFO:root:Round 164:Pareto update
# INFO:root:Round 164:Useful update
# INFO:root:Round 164:There are 99 designs left in set S and 0 designs in set P.
# INFO:root:Round 164:Sample count 164
# INFO:root:Round 165:Evaluating
# INFO:root:Round 165:Modeling
# INFO:root:Round 165:Discarding
# INFO:root:Round 165:Pareto update
# INFO:root:Round 165:Useful update
# INFO:root:Round 165:There are 99 designs left in set S and 0 designs in set P.
# INFO:root:Round 165:Sample count 165
# INFO:root:Round 166:Evaluating
# INFO:root:Round 166:Modeling
# INFO:root:Round 166:Discarding
# INFO:root:Round 166:Pareto update
# INFO:root:Round 166:Useful update
# INFO:root:Round 166:There are 99 designs left in set S and 0 designs in set P.
# INFO:root:Round 166:Sample count 166
# INFO:root:Round 167:Evaluating
# INFO:root:Round 167:Modeling
# INFO:root:Round 167:Discarding
# INFO:root:Round 167:Pareto update
# INFO:root:Round 167:Useful update
# INFO:root:Round 167:There are 98 designs left in set S and 0 designs in set P.
# INFO:root:Round 167:Sample count 167
# INFO:root:Round 168:Evaluating
# INFO:root:Round 168:Modeling
# INFO:root:Round 168:Discarding
# INFO:root:Round 168:Pareto update
# INFO:root:Round 168:Useful update
# INFO:root:Round 168:There are 98 designs left in set S and 0 designs in set P.
# INFO:root:Round 168:Sample count 168
# INFO:root:Round 169:Evaluating
# INFO:root:Round 169:Modeling
# INFO:root:Round 169:Discarding
# INFO:root:Round 169:Pareto update
# INFO:root:Round 169:Useful update
# INFO:root:Round 169:There are 97 designs left in set S and 0 designs in set P.
# INFO:root:Round 169:Sample count 169
# INFO:root:Round 170:Evaluating
# INFO:root:Round 170:Modeling
# INFO:root:Round 170:Discarding
# INFO:root:Round 170:Pareto update
# INFO:root:Round 170:Useful update
# INFO:root:Round 170:There are 97 designs left in set S and 0 designs in set P.
# INFO:root:Round 170:Sample count 170
# INFO:root:Round 171:Evaluating
# INFO:root:Round 171:Modeling
# INFO:root:Round 171:Discarding
# INFO:root:Round 171:Pareto update
# INFO:root:Round 171:Useful update
# INFO:root:Round 171:There are 97 designs left in set S and 0 designs in set P.
# INFO:root:Round 171:Sample count 171
# INFO:root:Round 172:Evaluating
# INFO:root:Round 172:Modeling
# INFO:root:Round 172:Discarding
# INFO:root:Round 172:Pareto update
# INFO:root:Round 172:Useful update
# INFO:root:Round 172:There are 96 designs left in set S and 0 designs in set P.
# INFO:root:Round 172:Sample count 172
# INFO:root:Round 173:Evaluating
# INFO:root:Round 173:Modeling
# INFO:root:Round 173:Discarding
# INFO:root:Round 173:Pareto update
# INFO:root:Round 173:Useful update
# INFO:root:Round 173:There are 95 designs left in set S and 0 designs in set P.
# INFO:root:Round 173:Sample count 173
# INFO:root:Round 174:Evaluating
# INFO:root:Round 174:Modeling
# INFO:root:Round 174:Discarding
# INFO:root:Round 174:Pareto update
# INFO:root:Round 174:Useful update
# INFO:root:Round 174:There are 94 designs left in set S and 0 designs in set P.
# INFO:root:Round 174:Sample count 174
# INFO:root:Round 175:Evaluating
# INFO:root:Round 175:Modeling
# INFO:root:Round 175:Discarding
# INFO:root:Round 175:Pareto update
# INFO:root:Round 175:Useful update
# INFO:root:Round 175:There are 93 designs left in set S and 0 designs in set P.
# INFO:root:Round 175:Sample count 175
# INFO:root:Round 176:Evaluating
# INFO:root:Round 176:Modeling
# INFO:root:Round 176:Discarding
# INFO:root:Round 176:Pareto update
# INFO:root:Round 176:Useful update
# INFO:root:Round 176:There are 92 designs left in set S and 0 designs in set P.
# INFO:root:Round 176:Sample count 176
# INFO:root:Round 177:Evaluating
# INFO:root:Round 177:Modeling
# INFO:root:Round 177:Discarding
# INFO:root:Round 177:Pareto update
# INFO:root:Round 177:Useful update
# INFO:root:Round 177:There are 91 designs left in set S and 0 designs in set P.
# ...
# INFO:root:Round 2273:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2273:Sample count 2273
# INFO:root:Round 2274:Evaluating
# INFO:root:Round 2274:Modeling
# INFO:root:Round 2274:Discarding
# INFO:root:Round 2274:Pareto update
# INFO:root:Round 2274:Useful update
# INFO:root:Round 2274:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2274:Sample count 2274
# INFO:root:Round 2275:Evaluating
# INFO:root:Round 2275:Modeling
# INFO:root:Round 2275:Discarding
# INFO:root:Round 2275:Pareto update
# INFO:root:Round 2275:Useful update
# INFO:root:Round 2275:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2275:Sample count 2275
# INFO:root:Round 2276:Evaluating
# INFO:root:Round 2276:Modeling
# INFO:root:Round 2276:Discarding
# INFO:root:Round 2276:Pareto update
# INFO:root:Round 2276:Useful update
# INFO:root:Round 2276:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2276:Sample count 2276
# INFO:root:Round 2277:Evaluating
# INFO:root:Round 2277:Modeling
# INFO:root:Round 2277:Discarding
# INFO:root:Round 2277:Pareto update
# INFO:root:Round 2277:Useful update
# INFO:root:Round 2277:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2277:Sample count 2277
# INFO:root:Round 2278:Evaluating
# INFO:root:Round 2278:Modeling
# INFO:root:Round 2278:Discarding
# INFO:root:Round 2278:Pareto update
# INFO:root:Round 2278:Useful update
# INFO:root:Round 2278:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2278:Sample count 2278
# INFO:root:Round 2279:Evaluating
# INFO:root:Round 2279:Modeling
# INFO:root:Round 2279:Discarding
# INFO:root:Round 2279:Pareto update
# INFO:root:Round 2279:Useful update
# INFO:root:Round 2279:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2279:Sample count 2279
# INFO:root:Round 2280:Evaluating
# INFO:root:Round 2280:Modeling
# INFO:root:Round 2280:Discarding
# INFO:root:Round 2280:Pareto update
# INFO:root:Round 2280:Useful update
# INFO:root:Round 2280:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2280:Sample count 2280
# INFO:root:Round 2281:Evaluating
# INFO:root:Round 2281:Modeling
# INFO:root:Round 2281:Discarding
# INFO:root:Round 2281:Pareto update
# INFO:root:Round 2281:Useful update
# INFO:root:Round 2281:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2281:Sample count 2281
# INFO:root:Round 2282:Evaluating
# INFO:root:Round 2282:Modeling
# INFO:root:Round 2282:Discarding
# INFO:root:Round 2282:Pareto update
# INFO:root:Round 2282:Useful update
# INFO:root:Round 2282:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2282:Sample count 2282
# INFO:root:Round 2283:Evaluating
# INFO:root:Round 2283:Modeling
# INFO:root:Round 2283:Discarding
# INFO:root:Round 2283:Pareto update
# INFO:root:Round 2283:Useful update
# INFO:root:Round 2283:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2283:Sample count 2283
# INFO:root:Round 2284:Evaluating
# INFO:root:Round 2284:Modeling
# INFO:root:Round 2284:Discarding
# INFO:root:Round 2284:Pareto update
# INFO:root:Round 2284:Useful update
# INFO:root:Round 2284:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2284:Sample count 2284
# INFO:root:Round 2285:Evaluating
# INFO:root:Round 2285:Modeling
# INFO:root:Round 2285:Discarding
# INFO:root:Round 2285:Pareto update
# INFO:root:Round 2285:Useful update
# INFO:root:Round 2285:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2285:Sample count 2285
# INFO:root:Round 2286:Evaluating
# INFO:root:Round 2286:Modeling
# INFO:root:Round 2286:Discarding
# INFO:root:Round 2286:Pareto update
# INFO:root:Round 2286:Useful update
# INFO:root:Round 2286:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2286:Sample count 2286
# INFO:root:Round 2287:Evaluating
# INFO:root:Round 2287:Modeling
# INFO:root:Round 2287:Discarding
# INFO:root:Round 2287:Pareto update
# INFO:root:Round 2287:Useful update
# INFO:root:Round 2287:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2287:Sample count 2287
# INFO:root:Round 2288:Evaluating
# INFO:root:Round 2288:Modeling
# INFO:root:Round 2288:Discarding
# INFO:root:Round 2288:Pareto update
# INFO:root:Round 2288:Useful update
# INFO:root:Round 2288:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2288:Sample count 2288
# INFO:root:Round 2289:Evaluating
# INFO:root:Round 2289:Modeling
# INFO:root:Round 2289:Discarding
# INFO:root:Round 2289:Pareto update
# INFO:root:Round 2289:Useful update
# INFO:root:Round 2289:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2289:Sample count 2289
# INFO:root:Round 2290:Evaluating
# INFO:root:Round 2290:Modeling
# INFO:root:Round 2290:Discarding
# INFO:root:Round 2290:Pareto update
# INFO:root:Round 2290:Useful update
# INFO:root:Round 2290:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2290:Sample count 2290
# INFO:root:Round 2291:Evaluating
# INFO:root:Round 2291:Modeling
# INFO:root:Round 2291:Discarding
# INFO:root:Round 2291:Pareto update
# INFO:root:Round 2291:Useful update
# INFO:root:Round 2291:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2291:Sample count 2291
# INFO:root:Round 2292:Evaluating
# INFO:root:Round 2292:Modeling
# INFO:root:Round 2292:Discarding
# INFO:root:Round 2292:Pareto update
# INFO:root:Round 2292:Useful update
# INFO:root:Round 2292:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2292:Sample count 2292
# INFO:root:Round 2293:Evaluating
# INFO:root:Round 2293:Modeling
# INFO:root:Round 2293:Discarding
# INFO:root:Round 2293:Pareto update
# INFO:root:Round 2293:Useful update
# INFO:root:Round 2293:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2293:Sample count 2293
# INFO:root:Round 2294:Evaluating
# INFO:root:Round 2294:Modeling
# INFO:root:Round 2294:Discarding
# INFO:root:Round 2294:Pareto update
# INFO:root:Round 2294:Useful update
# INFO:root:Round 2294:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2294:Sample count 2294
# INFO:root:Round 2295:Evaluating
# INFO:root:Round 2295:Modeling
# INFO:root:Round 2295:Discarding
# INFO:root:Round 2295:Pareto update
# INFO:root:Round 2295:Useful update
# INFO:root:Round 2295:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2295:Sample count 2295
# INFO:root:Round 2296:Evaluating
# INFO:root:Round 2296:Modeling
# INFO:root:Round 2296:Discarding
# INFO:root:Round 2296:Pareto update
# INFO:root:Round 2296:Useful update
# INFO:root:Round 2296:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2296:Sample count 2296
# INFO:root:Round 2297:Evaluating
# INFO:root:Round 2297:Modeling
# INFO:root:Round 2297:Discarding
# INFO:root:Round 2297:Pareto update
# INFO:root:Round 2297:Useful update
# INFO:root:Round 2297:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2297:Sample count 2297
# INFO:root:Round 2298:Evaluating
# INFO:root:Round 2298:Modeling
# INFO:root:Round 2298:Discarding
# INFO:root:Round 2298:Pareto update
# INFO:root:Round 2298:Useful update
# INFO:root:Round 2298:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2298:Sample count 2298
# INFO:root:Round 2299:Evaluating
# INFO:root:Round 2299:Modeling
# INFO:root:Round 2299:Discarding
# INFO:root:Round 2299:Pareto update
# INFO:root:Round 2299:Useful update
# INFO:root:Round 2299:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2299:Sample count 2299
# INFO:root:Round 2300:Evaluating
# INFO:root:Round 2300:Modeling
# INFO:root:Round 2300:Discarding
# INFO:root:Round 2300:Pareto update
# INFO:root:Round 2300:Useful update
# INFO:root:Round 2300:There are 2 designs left in set S and 3 designs in set P.
# INFO:root:Round 2300:Sample count 2300
# INFO:root:Round 2301:Evaluating
# INFO:root:Round 2301:Modeling
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#       7 algorithm = vopy.algorithms.PaVeBaGP(
#       8     epsilon=epsilon, delta=delta,
#       9     dataset_name=dataset_name, order=order, noise_var=noise_var,
#      10     type='IH'
#      11 )
#      13 while True:
# ---> 14     is_done = algorithm.run_one_step()
#      16     if is_done:
#      17         break
#
# File ~/works/vectoptal/vopy/algorithms/paveba_gp.py:234, in PaVeBaGP.run_one_step(self)
#     231 self.evaluating()
#     233 logging.info(f"{round_str}:Modeling")
# --> 234 self.modeling()
#     236 logging.info(f"{round_str}:Discarding")
#     237 self.discarding()
#
# File ~/works/vectoptal/vopy/algorithms/paveba_gp.py:130, in PaVeBaGP.modeling(self)
#     128 self.alpha_t = self.compute_alpha()
#     129 A = self.S.union(self.U)
# --> 130 self.design_space.update(self.model, self.alpha_t, list(A))
#
# File ~/works/vectoptal/vopy/design_space.py:151, in FixedPointsDesignSpace.update(self, model, scale, indices_to_update)
#     148 elif scale.ndim != 2 or len(scale) != len(indices_to_update):
#     149     raise ValueError("Invalid scale shape.")
# --> 151 mus, covs = model.predict(self.points[indices_to_update])
#     152 for pt_i, mu, cov, s in zip(indices_to_update, mus, covs, scale):
#     153     self.confidence_regions[pt_i].update(mu, cov, s)
#
# File ~/works/vectoptal/vopy/models/gpytorch.py:498, in IndependentExactGPyTorchModel.predict(self, test_X)
#     495 test_X = self.to_tensor(test_X)
#     497 with torch.no_grad(), torch.autograd.set_detect_anomaly(True):
# --> 498     res = self.model(test_X)
#     500     means = res.mean.squeeze().numpy(force=True)  # Squeeze the sample dimension
#     501     variances = torch.einsum("ij,ki->kij", torch.eye(self.output_dim), res.variance).numpy(
#     502         force=True
#     503     )
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/gpytorch/models/exact_gp.py:333, in ExactGP.__call__(self, *args, **kwargs)
#     328 # Make the prediction
#     329 with settings.cg_tolerance(settings.eval_cg_tolerance.value()):
#     330     (
#     331         predictive_mean,
#     332         predictive_covar,
# --> 333     ) = self.prediction_strategy.exact_prediction(full_mean, full_covar)
#     335 # Reshape predictive mean to match the appropriate event shape
#     336 predictive_mean = predictive_mean.view(*batch_shape, *test_shape).contiguous()
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/gpytorch/models/exact_prediction_strategies.py:290, in DefaultPredictionStrategy.exact_prediction(self, joint_mean, joint_covar)
#     285     test_test_covar = joint_covar[..., self.num_train :, self.num_train :]
#     286     test_train_covar = joint_covar[..., self.num_train :, : self.num_train]
#     288 return (
#     289     self.exact_predictive_mean(test_mean, test_train_covar),
# --> 290     self.exact_predictive_covar(test_test_covar, test_train_covar),
#     291 )
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/gpytorch/models/exact_prediction_strategies.py:342, in DefaultPredictionStrategy.exact_predictive_covar(self, test_test_covar, test_train_covar)
#     340 test_train_covar = to_dense(test_train_covar)
#     341 train_test_covar = test_train_covar.transpose(-1, -2)
# --> 342 covar_correction_rhs = train_train_covar.solve(train_test_covar)
#     343 # For efficiency
#     344 if torch.is_tensor(test_test_covar):
#     345     # We can use addmm in the 2d case
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/operators/_linear_operator.py:2334, in LinearOperator.solve(self, right_tensor, left_tensor)
#    2332 func = Solve
#    2333 if left_tensor is None:
# -> 2334     return func.apply(self.representation_tree(), False, right_tensor, *self.representation())
#    2335 else:
#    2336     return func.apply(
#    2337         self.representation_tree(),
#    2338         True,
#    (...)
#    2341         *self.representation(),
#    2342     )
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/torch/autograd/function.py:506, in Function.apply(cls, *args, **kwargs)
#     503 if not torch._C._are_functorch_transforms_active():
#     504     # See NOTE: [functorch vjp and autograd interaction]
#     505     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     508 if cls.setup_context == _SingleLevelFunction.setup_context:
#     509     raise RuntimeError(
#     510         'In order to use an autograd.Function with functorch transforms '
#     511         '(vmap, grad, jvp, jacrev, ...), it must override the setup_context '
#     512         'staticmethod. For more details, please see '
#     513         'https://pytorch.org/docs/master/notes/extending.func.html')
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/functions/_solve.py:53, in Solve.forward(ctx, representation_tree, has_left, *args)
#      51     res = left_tensor @ res
#      52 else:
# ---> 53     solves = _solve(linear_op, right_tensor)
#      54     res = solves
#      56 if ctx.is_vector:
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/functions/_solve.py:17, in _solve(linear_op, rhs)
#      15     return linear_op.solve(rhs)
#      16 if settings.fast_computations.solves.off() or linear_op.size(-1) <= settings.max_cholesky_size.value():
# ---> 17     return linear_op.cholesky()._cholesky_solve(rhs)
#      18 else:
#      19     with torch.no_grad():
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/operators/_linear_operator.py:1303, in LinearOperator.cholesky(self, upper)
#    1293 @_implements(torch.linalg.cholesky)
#    1294 def cholesky(
#    1295     self: Float[LinearOperator, "*batch N N"], upper: bool = False
#    1296 ) -> Float[LinearOperator, "*batch N N"]:  # returns TriangularLinearOperator
#    1297     """
#    1298     Cholesky-factorizes the LinearOperator.
#    1299
#    1300     :param upper: Upper triangular or lower triangular factor (default: False).
#    1301     :return: Cholesky factor (lower or upper triangular)
#    1302     """
# -> 1303     chol = self._cholesky(upper=False)
#    1304     if upper:
#    1305         chol = chol._transpose_nonbatch()
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/utils/memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/operators/_linear_operator.py:522, in LinearOperator._cholesky(self, upper)
#     519     return TriangularLinearOperator(evaluated_mat.clamp_min(0.0).sqrt())
#     521 # contiguous call is necessary here
# --> 522 cholesky = psd_safe_cholesky(evaluated_mat, upper=upper).contiguous()
#     523 return TriangularLinearOperator(cholesky, upper=upper)
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/utils/cholesky.py:65, in psd_safe_cholesky(A, upper, out, jitter, max_tries)
#      50 def psd_safe_cholesky(A, upper=False, out=None, jitter=None, max_tries=None):
#      51     """Compute the Cholesky decomposition of A. If A is only p.s.d, add a small jitter to the diagonal.
#      52     Args:
#      53         :attr:`A` (Tensor):
#    (...)
#      63             Number of attempts (with successively increasing jitter) to make before raising an error.
#      64     """
# ---> 65     L = _psd_safe_cholesky(A, out=out, jitter=jitter, max_tries=max_tries)
#      66     if upper:
#      67         if out is not None:
#
# File ~/micromamba/envs/torch/lib/python3.10/site-packages/linear_operator/utils/cholesky.py:20, in _psd_safe_cholesky(A, out, jitter, max_tries)
#      17 if out is not None:
#      18     out = (out, torch.empty(A.shape[:-2], dtype=torch.int32, device=out.device))
# ---> 20 L, info = torch.linalg.cholesky_ex(A, out=out)
#      21 if settings.trace_mode.on() or not torch.any(info):
#      22     return L
#
# KeyboardInterrupt:

# %% [markdown]
# The results show both Naive Elimination and PaVeBa achieve perfect results but with different number of samples. This is expected due to the nature of the algorithms. For details of the algorithms, see documentation for [vopy.algorithms](../algorithms.rst).
